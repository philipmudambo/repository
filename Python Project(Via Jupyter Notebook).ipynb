# %%
# import all the modules for this excercise
import urllib.request
import pandas as pd
url = "https://raw.githubusercontent.com/justmarkham/pycon-2018-tutorial/master/police.csv"
urllib.request.urlretrieve(url, "police.csv")
df = pd.read_csv("police.csv")
df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation  search_conducted  \
# 0        20.0       White          Speeding  Speeding             False
# 1        40.0       White          Speeding  Speeding             False
# 2        33.0       White          Speeding  Speeding             False
# 3        19.0       White  Call for Service     Other             False
# 4        21.0       White          Speeding  Speeding             False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
# load the data and display the first 6 rows?
df.head(6)
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
# 5  2005-03-23     09:45          NaN             M          1982.0
#
#    driver_age driver_race                   violation_raw  violation  \
# 0        20.0       White                        Speeding   Speeding
# 1        40.0       White                        Speeding   Speeding
# 2        33.0       White                        Speeding   Speeding
# 3        19.0       White                Call for Service      Other
# 4        21.0       White                        Speeding   Speeding
# 5        23.0       Black  Equipment/Inspection Violation  Equipment
#
# ...

# %%
# what do these numbers mean(How many rows and columns)?
num_rows, num_cols = data.shape
print(num_rows, "rows and", num_cols, "columns.")
# Out:
# 91741 rows and 15 columns.

# %%
# what is the datatype of each column
data_types = df.dtypes 
print(data_types)
# Out:
# stop_date              object
# stop_time              object
# county_name           float64
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
#Display the statistics values in every numeric column of the data frame.
print(df.describe())
# Out:
#        county_name  driver_age_raw    driver_age
# count          0.0    86414.000000  86120.000000
# mean           NaN     1970.491228     34.011333
# std            NaN      110.914909     12.738564
# min            NaN        0.000000     15.000000
# 25%            NaN     1967.000000     23.000000
# 50%            NaN     1980.000000     31.000000
# 75%            NaN     1987.000000     43.000000
# max            NaN     8801.000000     99.000000

# %%
# calculate the sum of all the NaN in each column?
print(df.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
# your code to remove the Columns and rows with NaN values
df = df.dropna(axis=1)
df = df.dropna()
print(df)
# Out:
#         stop_date stop_time  search_conducted  drugs_related_stop
# 0      2005-01-02     01:55             False               False
# 1      2005-01-18     08:15             False               False
# 2      2005-01-23     23:15             False               False
# 3      2005-02-20     17:15             False               False
# 4      2005-03-14     10:00             False               False
# ...           ...       ...               ...                 ...
# 91736  2015-12-31     20:27             False               False
# 91737  2015-12-31     20:35             False               False
# 91738  2015-12-31     20:45             False               False
# 91739  2015-12-31     21:42             False               False
# 91740  2015-12-31     22:46             False               False
#
# [91741 rows x 4 columns]

# %%
# Display the names of the columns in the dataframe
print(df.columns)
# Out:
# Index(['stop_date', 'stop_time', 'search_conducted', 'drugs_related_stop'], dtype='object')

# %%
#  Find the value counts for men and women
gender_counts = df['driver_gender'].value_counts()
print(gender_counts)
# Out:
# M    62895
# F    23511
# Name: driver_gender, dtype: int64

# %%
# Find the value counts for values in Violation column
violation_counts = data["violation"].value_counts()
print(violation_counts)
# Out:
# Speeding               48463
# Moving violation       16224
# Equipment              11020
# Other                   4317
# Registration/plates     3432
# Seat belt               2952
# Name: violation, dtype: int64

# %%
# create  filter and display the dataframe with people whove violation is 'Speeding'
speeding_df = df[df['violation'] == 'Speeding']
speeding_df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# 6      2005-04-01     17:30          NaN             M          1969.0
# ...           ...       ...          ...           ...             ...
# 91734  2015-12-31     20:20          NaN             M          1993.0
# 91735  2015-12-31     20:25          NaN             M          1992.0
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race violation_raw violation  search_conducted  \
# ...

# %%
# create a filter and display the dataframe with only male ?
df_male = df[df['driver_gender'] == 'M']
df_male
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 5      2005-03-23     09:45          NaN             M          1982.0
# ...           ...       ...          ...           ...             ...
# 91735  2015-12-31     20:25          NaN             M          1992.0
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
# create a filter and display the dataframe with only Female?
female_filter = data['driver_gender'] == 'F'
female_data = data[female_filter]
female_data
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 4      2005-03-14     10:00          NaN             F          1984.0
# 7      2005-06-06     13:20          NaN             F          1986.0
# 11     2005-07-13     19:00          NaN             F          1966.0
# 13     2005-07-18     19:30          NaN             F          1984.0
# 19     2005-07-24     20:10          NaN             F          1958.0
# ...           ...       ...          ...           ...             ...
# 91730  2015-12-31     15:36          NaN             F          1996.0
# 91731  2015-12-31     16:38          NaN             F          1988.0
# 91732  2015-12-31     19:44          NaN             F          1969.0
# 91733  2015-12-31     19:55          NaN             F          1974.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
# create a filter and display the dataframe with only Female
female_df = df[df['driver_gender'] == 'F']
female_df
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 4      2005-03-14     10:00          NaN             F          1984.0
# 7      2005-06-06     13:20          NaN             F          1986.0
# 11     2005-07-13     19:00          NaN             F          1966.0
# 13     2005-07-18     19:30          NaN             F          1984.0
# 19     2005-07-24     20:10          NaN             F          1958.0
# ...           ...       ...          ...           ...             ...
# 91730  2015-12-31     15:36          NaN             F          1996.0
# 91731  2015-12-31     16:38          NaN             F          1988.0
# 91732  2015-12-31     19:44          NaN             F          1969.0
# 91733  2015-12-31     19:55          NaN             F          1974.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
# Find the value counts on search conducted column
search_counts = df["search_conducted"].value_counts()
print(search_counts)
# Out:
# False    88545
# True      3196
# Name: search_conducted, dtype: int64

# %%
# Find the mean of the search conducted column
mean_search_conducted = police_df['search_conducted'].mean()
print("Mean of the search conducted column:", mean_search_conducted)
# Out:
# Mean of the search conducted column: 0.03483720473942948

# %%
# Create a filter when search conducted if false otherwise
search_filter = police_df['search_conducted'] == False
police_df.loc[~search_filter, 'search_conducted'] = 'Otherwise'
police_df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation search_conducted  \
# 0        20.0       White          Speeding  Speeding            False
# 1        40.0       White          Speeding  Speeding            False
# 2        33.0       White          Speeding  Speeding            False
# 3        19.0       White  Call for Service     Other            False
# 4        21.0       White          Speeding  Speeding            False
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
# Create a filter when search conducted if True otherwise
search_filter = police_df['search_conducted'] == True
police_df.loc[~search_filter, 'search_conducted'] = 'Otherwise'
police_df.head()
# Out:
#     stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0  2005-01-02     01:55          NaN             M          1985.0
# 1  2005-01-18     08:15          NaN             M          1965.0
# 2  2005-01-23     23:15          NaN             M          1972.0
# 3  2005-02-20     17:15          NaN             M          1986.0
# 4  2005-03-14     10:00          NaN             F          1984.0
#
#    driver_age driver_race     violation_raw violation search_conducted  \
# 0        20.0       White          Speeding  Speeding        Otherwise
# 1        40.0       White          Speeding  Speeding        Otherwise
# 2        33.0       White          Speeding  Speeding        Otherwise
# 3        19.0       White  Call for Service     Other        Otherwise
# 4        21.0       White          Speeding  Speeding        Otherwise
#
#   search_type   stop_outcome is_arrested stop_duration  drugs_related_stop
# ...

# %%
# create a filter for all values that have Protective Frisk in frisk column
protective_frisk_filter = df["frisk"] == "Protective Frisk"
df_filtered = df[protective_frisk_filter]
df_filtered
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frisk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Find the datatype pof the frisk column
frisk_datatype = police_df['Frisk'].dtype
print(frisk_datatype)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Frisk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Find the value counts for frisk column
frisk_value_counts = police_df['frisk'].value_counts()
print("Counts for the frisk column:\n", frisk_value_counts)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'frisk'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# find the value counts for stop_duration column
value_counts = data["stop_duration"].value_counts()
print(value_counts)
# Out:
# 0-15 Min     69543
# 16-30 Min    13635
# 30+ Min       3228
# 2                1
# 1                1
# Name: stop_duration, dtype: int64

# %%
# Filter the dataframe with people who have above the mean of the age
mean_age = df['age'].mean()
filtered_df = df[df['age'] > mean_age]
print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Filter the dataframe with people who have below the mean of the age
mean_age = police_df['age'].mean()
filtered_df = police_df[police_df['age'] < mean_age]
print(filtered_df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'age'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
